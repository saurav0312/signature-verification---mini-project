# %%
import sys
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time
import itertools
import random

from sklearn.utils import shuffle

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate, Dropout
from keras.models import Model

from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
path = "Hindi/"

# %%
# Get the list of all directories and sort them
dir_list = next(os.walk(path))[1]
dir_list.sort()

# %%
# For each person segregate the genuine signatures from the forged signatures
# Genuine signatures are stored in the list "orig_groups"
# Forged signatures are stored in the list "forged_groups"
orig_groups, forg_groups = [], []
for directory in dir_list:
    images = os.listdir(path+directory)
    images.sort()
    images = [path+directory+'/'+x for x in images]
    forg_groups.append(images[:20]) # First 30 signatures in each folder are forrged
    orig_groups.append(images[20:]) # Next 24 signatures are genuine

# %%
# Quick check to confirm we have data of all the 160 individuals
len(orig_groups), len(forg_groups)
# Out:
# (20, 20)

# %%
orig_lengths = [len(x) for x in orig_groups]
forg_lengths = [len(x) for x in forg_groups]

# %%
# Quick check to confirm that there are 24 Genuine signatures for each individual
print(orig_lengths)
# Out:
# [15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15]

# %%
# Quick check to confirm that there are 30 Forged signatures for each individual
print(forg_lengths)
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %% [markdown]
# #### Train-Validation-Test Split
# * Signatures of 120 people are used for training
# * Signatures of 20 people are used for validation
# * Signatures of 20 people are used for testing

# %%
orig_train, orig_val, orig_test = orig_groups[:10], orig_groups[10:15], orig_groups[15:]
forg_train, forg_val, forg_test = forg_groups[:10], forg_groups[10:15], forg_groups[15:]

# %%
# Delete unnecessary variables
del orig_groups, forg_groups

# %%
# All the images will be converted to the same size before processing
img_h, img_w = 155, 220

# %%
def visualize_sample_signature():
    '''Function to randomly select a signature from train set and
    print two genuine copies and one forged copy'''
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (10, 10))
    k = np.random.randint(len(orig_train))
    orig_img_names = random.sample(orig_train[k], 2)
    forg_img_name = random.sample(forg_train[k], 1)
    orig_img1 = cv2.imread(orig_img_names[0], 0)
    orig_img2 = cv2.imread(orig_img_names[1], 0)
    forg_img = plt.imread(forg_img_name[0], 0)
    orig_img1 = cv2.resize(orig_img1, (img_w, img_h))
    orig_img2 = cv2.resize(orig_img2, (img_w, img_h))
    forg_img = cv2.resize(forg_img, (img_w, img_h))

    ax1.imshow(orig_img1, cmap = 'gray')
    ax2.imshow(orig_img2, cmap = 'gray')
    ax3.imshow(forg_img, cmap = 'gray')

    ax1.set_title('Genuine Copy')
    ax1.axis('off')
    ax2.set_title('Genuine Copy')
    ax2.axis('off')
    ax3.set_title('Forged Copy')
    ax3.axis('off')

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
def generate_batch(orig_groups, forg_groups, batch_size = 32):
    '''Function to generate a batch of data with batch_size number of data points
    Half of the data points will be Genuine-Genuine pairs and half will be Genuine-Forged pairs'''
    while True:
        orig_pairs = []
        forg_pairs = []
        gen_gen_labels = []
        gen_for_labels = []
        all_pairs = []
        all_labels = []
        
        # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
        # For every person we have 15 genuine signatures, hence we have 
        # 15 choose 2 = 105 Genuine-Genuine image pairs for one person.
        # To make Genuine-Forged pairs, we pair every Genuine signature of a person
        # with 12 randomly sampled Forged signatures of the same person.
        # Thus we make 15 * 12 = 180 Genuine-Forged image pairs for one person.
        # In all we have 20 person's data in the training data.
        # Total no. of Genuine-Genuine pairs = 10 * 105 = 1050
        # Total number of Genuine-Forged pairs = 10 * 180 = 1800
        # Total no. of data points = 1050 + 1800 =2850
        for orig, forg in zip(orig_groups, forg_groups):
            orig_pairs.extend(list(itertools.combinations(orig, 2)))
            for i in range(len(forg)):
                forg_pairs.extend(list(itertools.product(orig[i:i+1], random.sample(forg, 12))))
        
        # Label for Genuine-Genuine pairs is 1
        # Label for Genuine-Forged pairs is 0
        gen_gen_labels = [1]*len(orig_pairs)
        gen_for_labels = [0]*len(forg_pairs)
        
        # Concatenate all the pairs together along with their labels and shuffle them
        all_pairs = orig_pairs + forg_pairs
        all_labels = gen_gen_labels + gen_for_labels
        del orig_pairs, forg_pairs, gen_gen_labels, gen_for_labels
        all_pairs, all_labels = shuffle(all_pairs, all_labels)
        
        # Note the lists above contain only the image names and
        # actual images are loaded and yielded below in batches
        # Below we prepare a batch of data points and yield the batch
        # In each batch we load "batch_size" number of image pairs
        # These images are then removed from the original set so that
        # they are not added again in the next batch.
            
        k = 0
        pairs=[np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
        targets=np.zeros((batch_size,))
        for ix, pair in enumerate(all_pairs):
            img1 = cv2.imread(pair[0], 0)
            img2 = cv2.imread(pair[1], 0)
            img1 = cv2.resize(img1, (img_w, img_h))
            img2 = cv2.resize(img2, (img_w, img_h))
            img1 = np.array(img1, dtype = np.float64)
            img2 = np.array(img2, dtype = np.float64)
            img1 /= 255
            img2 /= 255
            img1 = img1[..., np.newaxis]
            img2 = img2[..., np.newaxis]
            pairs[0][k, :, :, :] = img1
            pairs[1][k, :, :, :] = img2
            targets[k] = all_labels[ix]
            k += 1
            if k == batch_size:
                yield pairs, targets
                k = 0
                pairs=[np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
                targets=np.zeros((batch_size,))

# %%
def euclidean_distance(vects):
    '''Compute Euclidean Distance between two vectors'''
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
def contrastive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    margin = 1
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))

# %%
def create_base_network_signet(input_shape):
    '''Base Siamese Network'''
    
    seq = Sequential()
    seq.add(Conv2D(96, kernel_size=(11, 11), activation='relu', name='conv1_1', strides=4, input_shape= input_shape, 
                        init='glorot_uniform', dim_ordering='tf'))
    seq.add(BatchNormalization(epsilon=1e-06, mode=0, axis=1, momentum=0.9))
    seq.add(MaxPooling2D((3,3), strides=(2, 2)))    
    seq.add(ZeroPadding2D((2, 2), dim_ordering='tf'))
    
    seq.add(Conv2D(256, kernel_size=(5, 5), activation='relu', name='conv2_1', strides=1, init='glorot_uniform',  dim_ordering='tf'))
    seq.add(BatchNormalization(epsilon=1e-06, mode=0, axis=1, momentum=0.9))
    seq.add(MaxPooling2D((3,3), strides=(2, 2)))
    seq.add(Dropout(0.3))# added extra
    seq.add(ZeroPadding2D((1, 1), dim_ordering='tf'))
    
    seq.add(Conv2D(384, kernel_size=(3, 3), activation='relu', name='conv3_1', strides=1, init='glorot_uniform',  dim_ordering='tf'))
    seq.add(ZeroPadding2D((1, 1), dim_ordering='tf'))
    
    seq.add(Conv2D(256, kernel_size=(3, 3), activation='relu', name='conv3_2', strides=1, init='glorot_uniform', dim_ordering='tf'))    
    seq.add(MaxPooling2D((3,3), strides=(2, 2)))
    seq.add(Dropout(0.3))# added extra
    seq.add(Flatten(name='flatten'))
    seq.add(Dense(1024, W_regularizer=l2(0.0005), activation='relu', init='glorot_uniform'))
    seq.add(Dropout(0.5))
    
    seq.add(Dense(128, W_regularizer=l2(0.0005), activation='relu', init='glorot_uniform')) # softmax changed to relu
    
    return seq

# %%
input_shape=(img_h, img_w, 1)

# %%
# network definition
base_network = create_base_network_signet(input_shape)

input_a = Input(shape=(input_shape))
input_b = Input(shape=(input_shape))

# because we re-use the same instance `base_network`,
# the weights of the network
# will be shared across the two branches
processed_a = base_network(input_a)
processed_b = base_network(input_b)

# Compute the Euclidean distance between the two vectors in the latent space
distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([processed_a, processed_b])

model = Model(input=[input_a, input_b], output=distance)
# Out:
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, kernel_size=(11, 11), activation="relu", name="conv1_1", strides=4, input_shape=(155, 220,..., data_format="channels_last", kernel_initializer="glorot_uniform")`
#
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(epsilon=1e-06, axis=1, momentum=0.9)`
#   import sys
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D((2, 2), data_format="channels_last")`
#   if __name__ == '__main__':
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(5, 5), activation="relu", name="conv2_1", strides=1, data_format="channels_last", kernel_initializer="glorot_uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(epsilon=1e-06, axis=1, momentum=0.9)`
#   if sys.path[0] == '':
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D((1, 1), data_format="channels_last")`
#   from ipykernel import kernelapp as app
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(384, kernel_size=(3, 3), activation="relu", name="conv3_1", strides=1, data_format="channels_last", kernel_initializer="glorot_uniform")`
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D((1, 1), data_format="channels_last")`
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), activation="relu", name="conv3_2", strides=1, data_format="channels_last", kernel_initializer="glorot_uniform")`
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1024, activation="relu", kernel_initializer="glorot_uniform", kernel_regularizer=<keras.reg...)`
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:27: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, activation="relu", kernel_initializer="glorot_uniform", kernel_regularizer=<keras.reg...)`
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("la...)`
#   app.launch_new_instance()

# %%
batch_sz = 128
num_train_samples = 105*10 + 180*10
num_val_samples = num_test_samples = 105*5 + 180*5
num_train_samples, num_val_samples, num_test_samples
# Out:
# (2850, 1425, 1425)

# %%
# compile model using RMSProp Optimizer and Contrastive loss function defined above
rms = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08)
model.compile(loss=contrastive_loss, optimizer=rms)

# %%
# Using Keras Callbacks, save the model after every epoch
# Reduce the learning rate by a factor of 0.1 if the validation loss does not improve for 5 epochs
# Stop the training using early stopping if the validation loss does not improve for 12 epochs
callbacks = [
    EarlyStopping(patience=12, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('CopyWeight/signet-bhsig260-{epoch:03d}.h5', verbose=1, save_weights_only=True)
]

# %%
results = model.fit_generator(generate_batch(orig_train, forg_train, batch_sz),
                              steps_per_epoch = num_train_samples//batch_sz,
                              epochs = 100,
                              validation_data = generate_batch(orig_val, forg_val, batch_sz),
                              validation_steps = num_val_samples//batch_sz,
                              callbacks = callbacks)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1878s 85s/step - loss: 7.8330 - val_loss: 1.4883
#
# Epoch 00001: saving model to CopyWeight/signet-bhsig260-001.h5
# Epoch 2/100
# 22/22 [==============================] - 1807s 82s/step - loss: 1.1685 - val_loss: 1.5057
#
# Epoch 00002: saving model to CopyWeight/signet-bhsig260-002.h5
# Epoch 3/100
# 22/22 [==============================] - 1792s 81s/step - loss: 1.1508 - val_loss: 1.4870
#
# Epoch 00003: saving model to CopyWeight/signet-bhsig260-003.h5
# Epoch 4/100
# 22/22 [==============================] - 1799s 82s/step - loss: 1.1642 - val_loss: 1.5044
#
# Epoch 00004: saving model to CopyWeight/signet-bhsig260-004.h5
# Epoch 5/100
# 22/22 [==============================] - 1790s 81s/step - loss: 1.1467 - val_loss: 1.4733
#
# Epoch 00005: saving model to CopyWeight/signet-bhsig260-005.h5
# Epoch 6/100
# 22/22 [==============================] - 1807s 82s/step - loss: 1.1128 - val_loss: 1.4207
#
# Epoch 00006: saving model to CopyWeight/signet-bhsig260-006.h5
# Epoch 7/100
# 22/22 [==============================] - 1796s 82s/step - loss: 1.0575 - val_loss: 1.3658
#
# Epoch 00007: saving model to CopyWeight/signet-bhsig260-007.h5
# Epoch 8/100
# 22/22 [==============================] - 1800s 82s/step - loss: 0.9852 - val_loss: 1.3007
#
# Epoch 00008: saving model to CopyWeight/signet-bhsig260-008.h5
# Epoch 9/100
# 22/22 [==============================] - 1787s 81s/step - loss: 0.9118 - val_loss: 1.2222
#
# Epoch 00009: saving model to CopyWeight/signet-bhsig260-009.h5
# Epoch 10/100
# 22/22 [==============================] - 1788s 81s/step - loss: 0.8286 - val_loss: 1.1579
#
# Epoch 00010: saving model to CopyWeight/signet-bhsig260-010.h5
# Epoch 11/100
# 22/22 [==============================] - 1778s 81s/step - loss: 0.7733 - val_loss: 1.1128
#
# Epoch 00011: saving model to CopyWeight/signet-bhsig260-011.h5
# Epoch 12/100
# 22/22 [==============================] - 1786s 81s/step - loss: 0.7219 - val_loss: 1.0463
#
# Epoch 00012: saving model to CopyWeight/signet-bhsig260-012.h5
# Epoch 13/100
# 22/22 [==============================] - 1787s 81s/step - loss: 0.6698 - val_loss: 0.9965
#
# Epoch 00013: saving model to CopyWeight/signet-bhsig260-013.h5
# Epoch 14/100
# 22/22 [==============================] - 1700s 77s/step - loss: 0.6201 - val_loss: 0.9521
#
# Epoch 00014: saving model to CopyWeight/signet-bhsig260-014.h5
# Epoch 15/100
# 22/22 [==============================] - 1141s 52s/step - loss: 0.5755 - val_loss: 0.9155
#
# Epoch 00015: saving model to CopyWeight/signet-bhsig260-015.h5
# Epoch 16/100
# 22/22 [==============================] - 1178s 54s/step - loss: 0.5280 - val_loss: 0.8835
#
# Epoch 00016: saving model to CopyWeight/signet-bhsig260-016.h5
# Epoch 17/100
# 22/22 [==============================] - 940s 43s/step - loss: 0.5032 - val_loss: 0.8483
#
# Epoch 00017: saving model to CopyWeight/signet-bhsig260-017.h5
# Epoch 18/100
# 22/22 [==============================] - 961s 44s/step - loss: 0.4783 - val_loss: 0.8228
#
# Epoch 00018: saving model to CopyWeight/signet-bhsig260-018.h5
# Epoch 19/100
# 22/22 [==============================] - 953s 43s/step - loss: 0.4544 - val_loss: 0.8093
#
# Epoch 00019: saving model to CopyWeight/signet-bhsig260-019.h5
# Epoch 20/100
# 22/22 [==============================] - 935s 42s/step - loss: 0.4324 - val_loss: 0.7868
#
# Epoch 00020: saving model to CopyWeight/signet-bhsig260-020.h5
# Epoch 21/100
# 22/22 [==============================] - 938s 43s/step - loss: 0.4189 - val_loss: 0.7784
#
# Epoch 00021: saving model to CopyWeight/signet-bhsig260-021.h5
# Epoch 22/100
# 22/22 [==============================] - 928s 42s/step - loss: 0.4040 - val_loss: 0.7634
#
# Epoch 00022: saving model to CopyWeight/signet-bhsig260-022.h5
# Epoch 23/100
# 22/22 [==============================] - 927s 42s/step - loss: 0.3950 - val_loss: 0.7575
#
# Epoch 00023: saving model to CopyWeight/signet-bhsig260-023.h5
# Epoch 24/100
# 22/22 [==============================] - 930s 42s/step - loss: 0.3799 - val_loss: 0.7472
#
# Epoch 00024: saving model to CopyWeight/signet-bhsig260-024.h5
# Epoch 25/100
# 22/22 [==============================] - 929s 42s/step - loss: 0.3741 - val_loss: 0.7398
#
# Epoch 00025: saving model to CopyWeight/signet-bhsig260-025.h5
# Epoch 26/100
# 22/22 [==============================] - 962s 44s/step - loss: 0.3671 - val_loss: 0.7294
#
# Epoch 00026: saving model to CopyWeight/signet-bhsig260-026.h5
# Epoch 27/100
# 22/22 [==============================] - 1039s 47s/step - loss: 0.3582 - val_loss: 0.7214
#
# Epoch 00027: saving model to CopyWeight/signet-bhsig260-027.h5
# Epoch 28/100
# 22/22 [==============================] - 1000s 45s/step - loss: 0.3491 - val_loss: 0.7046
#
# Epoch 00028: saving model to CopyWeight/signet-bhsig260-028.h5
# Epoch 29/100
# 22/22 [==============================] - 933s 42s/step - loss: 0.3487 - val_loss: 0.6861
#
# Epoch 00029: saving model to CopyWeight/signet-bhsig260-029.h5
# Epoch 30/100
# 22/22 [==============================] - 933s 42s/step - loss: 0.3366 - val_loss: 0.6835
#
# Epoch 00030: saving model to CopyWeight/signet-bhsig260-030.h5
# Epoch 31/100
# 22/22 [==============================] - 1181s 54s/step - loss: 0.3335 - val_loss: 0.6802
#
# Epoch 00031: saving model to CopyWeight/signet-bhsig260-031.h5
# Epoch 32/100
# 22/22 [==============================] - 1719s 78s/step - loss: 0.3300 - val_loss: 0.6518
#
# Epoch 00032: saving model to CopyWeight/signet-bhsig260-032.h5
# Epoch 33/100
# 22/22 [==============================] - 1373s 62s/step - loss: 0.3340 - val_loss: 0.6160
#
# Epoch 00033: saving model to CopyWeight/signet-bhsig260-033.h5
# Epoch 34/100
# 22/22 [==============================] - 931s 42s/step - loss: 0.3229 - val_loss: 0.5756
#
# Epoch 00034: saving model to CopyWeight/signet-bhsig260-034.h5
# Epoch 35/100
# 22/22 [==============================] - 929s 42s/step - loss: 0.3072 - val_loss: 0.5386
#
# Epoch 00035: saving model to CopyWeight/signet-bhsig260-035.h5
# Epoch 36/100
# 22/22 [==============================] - 925s 42s/step - loss: 0.3040 - val_loss: 0.4956
#
# Epoch 00036: saving model to CopyWeight/signet-bhsig260-036.h5
# Epoch 37/100
# 22/22 [==============================] - 930s 42s/step - loss: 0.2942 - val_loss: 0.3896
#
# Epoch 00037: saving model to CopyWeight/signet-bhsig260-037.h5
# Epoch 38/100
# 22/22 [==============================] - 928s 42s/step - loss: 0.3557 - val_loss: 0.3978
#
# Epoch 00038: saving model to CopyWeight/signet-bhsig260-038.h5
# Epoch 39/100
# 22/22 [==============================] - 929s 42s/step - loss: 0.2578 - val_loss: 0.3514
#
# Epoch 00039: saving model to CopyWeight/signet-bhsig260-039.h5
# Epoch 40/100
# 22/22 [==============================] - 929s 42s/step - loss: 0.2329 - val_loss: 0.3019
#
# Epoch 00040: saving model to CopyWeight/signet-bhsig260-040.h5
# Epoch 41/100
# 22/22 [==============================] - 930s 42s/step - loss: 0.2161 - val_loss: 0.3068
#
# Epoch 00041: saving model to CopyWeight/signet-bhsig260-041.h5
# Epoch 42/100
# 22/22 [==============================] - 935s 43s/step - loss: 0.1918 - val_loss: 0.3012
#
# Epoch 00042: saving model to CopyWeight/signet-bhsig260-042.h5
# Epoch 43/100
# 22/22 [==============================] - 929s 42s/step - loss: 0.1547 - val_loss: 0.2993
#
# Epoch 00043: saving model to CopyWeight/signet-bhsig260-043.h5
# Epoch 44/100
# 22/22 [==============================] - 923s 42s/step - loss: nan - val_loss: nan
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\keras\callbacks.py:543: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# C:\Users\Saurav\Anaconda3\envs\tensorflow\lib\site-packages\keras\callbacks.py:1090: RuntimeWarning: invalid value encountered in less
#   self.monitor_op = lambda a, b: np.less(a, b - self.min_delta)
# Epoch 00044: saving model to CopyWeight/signet-bhsig260-044.h5
# Epoch 45/100
# 22/22 [==============================] - 921s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00045: saving model to CopyWeight/signet-bhsig260-045.h5
# Epoch 46/100
# 22/22 [==============================] - 919s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00046: saving model to CopyWeight/signet-bhsig260-046.h5
# Epoch 47/100
# 22/22 [==============================] - 918s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00047: saving model to CopyWeight/signet-bhsig260-047.h5
# Epoch 48/100
# 22/22 [==============================] - 919s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00048: saving model to CopyWeight/signet-bhsig260-048.h5
# Epoch 49/100
# 22/22 [==============================] - 920s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00049: saving model to CopyWeight/signet-bhsig260-049.h5
# Epoch 50/100
# 22/22 [==============================] - 918s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00050: saving model to CopyWeight/signet-bhsig260-050.h5
# Epoch 51/100
# 22/22 [==============================] - 917s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00051: saving model to CopyWeight/signet-bhsig260-051.h5
# Epoch 52/100
# 22/22 [==============================] - 918s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00052: saving model to CopyWeight/signet-bhsig260-052.h5
# Epoch 53/100
# 22/22 [==============================] - 920s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00053: saving model to CopyWeight/signet-bhsig260-053.h5
# Epoch 54/100
# 22/22 [==============================] - 917s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00054: saving model to CopyWeight/signet-bhsig260-054.h5
# Epoch 55/100
# 22/22 [==============================] - 919s 42s/step - loss: nan - val_loss: nan
#
# Epoch 00055: saving model to CopyWeight/signet-bhsig260-055.h5
# Epoch 00055: early stopping

# %% [markdown]
# #### After observing continuous fall in validation accuracy, I interrupted the training manually

# %%
def compute_accuracy_roc(predictions, labels):
    '''Compute ROC accuracy with a range of thresholds on distances.
    '''
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1)
    ndiff = np.sum(labels == 0)
   
    step = 0.01
    max_acc = 0
    best_thresh = -1
   
    for d in np.arange(dmin, dmax+step, step):
        idx1 = predictions.ravel() <= d
        idx2 = predictions.ravel() > d
       
        tpr = float(np.sum(labels[idx1] == 1)) / nsame       
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff
        acc = 0.5 * (tpr + tnr)       
#       print ('ROC', acc, tpr, tnr)
       
        if (acc > max_acc):
            max_acc, best_thresh = acc, d
           
    return max_acc, best_thresh

# %% [markdown]
# #### Load the weights from the epoch which gave the best validation accuracy

# %%
model.load_weights('CopyWeight/signet-bhsig260-043.h5')

# %%
test_gen = generate_batch(orig_test, forg_test, 1)
pred, tr_y = [], []
for i in range(num_test_samples):
    (img1, img2), label = next(test_gen)
    tr_y.append(label)
    pred.append(model.predict([img1, img2])[0][0])

# %%
tr_acc, threshold = compute_accuracy_roc(np.array(pred), np.array(tr_y))
tr_acc, threshold
# Out:
# (0.7138888888888889, 0.5495182043313978)

# %% [markdown]
# #### Accuracy = 81.71% and Threshold = 0.55
# Thus if the differnce score is less than 0.55, we predict the test image as Genuine and if the difference score is greater than 0.55, we predict it to be as forged
#
# #### Below we see some sample results

# %%
def predict_score():
    '''Predict distance score and classify test images as Genuine or Forged'''
    test_point, test_label = next(test_gen)
    img1, img2 = test_point[0], test_point[1]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 10))
    ax1.imshow(np.squeeze(img1), cmap='gray')
    ax2.imshow(np.squeeze(img2), cmap='gray')
    ax1.set_title('Genuine')
    if test_label == 1:
        ax2.set_title('Genuine')
    else:
        ax2.set_title('Forged')
    ax1.axis('off')
    ax2.axis('off')
    plt.show()
    result = model.predict([img1, img2])
    diff = result[0][0]
    print("Difference Score = ", diff)
    if diff > threshold:
        print("Its a Forged Signature")
    else:
        print("Its a Genuine Signature")

# %%
predict_score()
# Out:
# Difference Score =  0.8923152
# Its a Forged Signature

# %% [markdown]
# ### Note: The first image is always Genuine. Score prediction and classification is done for the second image

# %%
predict_score()
# Out:
# Difference Score =  1.5718569
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.1110314
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.4200523
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.93642324
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.4636926
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.295069
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.92126
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.0295221
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.6782455
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.3220205
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.75327426
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.198973
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.0658648
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.028276775
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.14532466
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.42529866
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.5412746
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.7716991
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.22233899
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.4042654
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.0046115727
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.9337214
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.2939676
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.12535787
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  1.5029047
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.42879045
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.23687324
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.610156
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.26007065
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.7205819
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.25164193
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.38825786
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.676633
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.0987293
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.8815795
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  1.207816
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.1395914
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.5675886
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.98273134
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.0066289324
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.119971395
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.4253973
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.057567514
# Its a Genuine Signature

# %%
from sklearn import metrics
import seaborn as sns

# %%
def pretty_cm(y_pred, y_truth, labels):
    # pretty implementation of a confusion matrix
    cm = metrics.confusion_matrix(y_truth, y_pred)
    ax= plt.subplot()
    sns.heatmap(cm, annot=True, fmt="d", linewidths=.5, square = True, cmap = 'BuGn_r')
    # labels, title and ticks
    ax.set_xlabel('Predicted label')
    ax.set_ylabel('Actual label')
    ax.set_title('Accuracy: {0}'.format(metrics.accuracy_score(y_truth, y_pred)), size = 15) 
    ax.xaxis.set_ticklabels(labels)
    ax.yaxis.set_ticklabels(labels)

# %%
test_gen = generate_batch(orig_test, forg_test, 1)
pred, tr_y = [], []
for i in range(num_test_samples):
    (img1, img2), label = next(test_gen)
    tr_y.append(label)
    diff=model.predict([img1,img2])[0][0]
    if diff > threshold:
        pred.append(0)
    else:
        pred.append(1)

# %%
pretty_cm(pred, tr_y, ['Genuine', 'Forge'])
